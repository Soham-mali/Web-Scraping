# %% [markdown]
# ## Web scriping from wikipedia on companies of US

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)

# %%
soup.find('table')

# %%
soup.find_all('table')[1]

# %%
soup.find('table', class_ = 'wikitable sortable')

# %%
table = soup.find_all('table')[1]

# %%
print(table)

# %%
world_titles = table.find_all('th')

# %%
world_titles

# %%
world_table_titles = [title.text.strip() for title in world_titles]

print(world_table_titles)

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df

# %%
df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Web Scraping\Folder for Output\Companies.csv', index = False)

# %% [markdown]
# # Top companies in share market india

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/BSE_SENSEX'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>BSE SENSEX - Wikipedia</title>
# ...

# %%
soup.find('table') # finds  table present in that webpage
# Out:
# <table class="infobox vcard"><caption class="infobox-title fn n org">BSE SENSEX</caption><tbody><tr class="logo"><td class="infobox-image" colspan="2"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:S%26P_BSE_Sensex_Logo_2022.svg"><img alt="Logo" class="mw-file-element" data-file-height="313" data-file-width="875" decoding="async" height="79" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/S%26P_BSE_Sensex_Logo_2022.svg/220px-S%26P_BSE_Sensex_Logo_2022.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/S%26P_BSE_Sensex_Logo_2022.svg/330px-S%26P_BSE_Sensex_Logo_2022.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/38/S%26P_BSE_Sensex_Logo_2022.svg/440px-S%26P_BSE_Sensex_Logo_2022.svg.png 2x" width="220"/></a></span></td></tr><tr><th class="infobox-label" scope="row">Foundation</th><td class="infobox-data">1 January 1986<span class="noprint"> (38 years ago)</span><span style="display:none"
# ...

# %%
soup.find_all('table')  # here we get all tables from that webpage
                        # <tr> for row , <td> for data for that row, <table class...> is name of table
# Out:
# [<table class="infobox vcard"><caption class="infobox-title fn n org">BSE SENSEX</caption><tbody><tr class="logo"><td class="infobox-image" colspan="2"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:S%26P_BSE_Sensex_Logo_2022.svg"><img alt="Logo" class="mw-file-element" data-file-height="313" data-file-width="875" decoding="async" height="79" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/S%26P_BSE_Sensex_Logo_2022.svg/220px-S%26P_BSE_Sensex_Logo_2022.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/S%26P_BSE_Sensex_Logo_2022.svg/330px-S%26P_BSE_Sensex_Logo_2022.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/38/S%26P_BSE_Sensex_Logo_2022.svg/440px-S%26P_BSE_Sensex_Logo_2022.svg.png 2x" width="220"/></a></span></td></tr><tr><th class="infobox-label" scope="row">Foundation</th><td class="infobox-data">1 January 1986<span class="noprint"> (38 years ago)</span><span style="display:none
# ...

# %%
# so i wanted first table having table class as "wikitable sortable" you can also go to that webpage and use adv tool to find name of table

soup.find_all('table')[1]    # we get first table in webpage using list and parameter 1
# Out:
# <table class="wikitable sortable" id="constituents">
# <tbody><tr>
# <th>Company
# </th>
# <th>Symbol
# </th>
# <th>Ticker Number
# </th>
# <th>Sector
# </th>
# <th>Entry date
# </th></tr>
# <tr>
# <th><a href="/wiki/Adani_Ports_%26_SEZ" title="Adani Ports &amp; SEZ">Adani Ports &amp; SEZ</a>
# </th>
# <td>ADANIPORTS.BO
# </td>
# <td>532921
# </td>
# <td><a class="mw-redirect" href="/wiki/Ports" title="Ports">Ports</a> &amp; <a href="/wiki/Port_management" title="Port management">Port services</a>
# </td>
# <td>24 June 2024<sup class="reference" id="cite_ref-jun24_8-0"><a href="#cite_note-jun24-8"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th><a href="/wiki/Asian_Paints" title="Asian Paints">Asian Paints</a>
# </th>
# <td>ASIANPAINT.BO
# </td>
# <td>500820
# </td>
# <td><a href="/wiki/Paint" title="Paint">Paints</a>
# </td>
# ...

# %%
soup.find('table', class_ = 'wikitable sortable')
# Out:
# <table class="wikitable sortable" id="constituents">
# <tbody><tr>
# <th>Company
# </th>
# <th>Symbol
# </th>
# <th>Ticker Number
# </th>
# <th>Sector
# </th>
# <th>Entry date
# </th></tr>
# <tr>
# <th><a href="/wiki/Adani_Ports_%26_SEZ" title="Adani Ports &amp; SEZ">Adani Ports &amp; SEZ</a>
# </th>
# <td>ADANIPORTS.BO
# </td>
# <td>532921
# </td>
# <td><a class="mw-redirect" href="/wiki/Ports" title="Ports">Ports</a> &amp; <a href="/wiki/Port_management" title="Port management">Port services</a>
# </td>
# <td>24 June 2024<sup class="reference" id="cite_ref-jun24_8-0"><a href="#cite_note-jun24-8"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th><a href="/wiki/Asian_Paints" title="Asian Paints">Asian Paints</a>
# </th>
# <td>ASIANPAINT.BO
# </td>
# <td>500820
# </td>
# <td><a href="/wiki/Paint" title="Paint">Paints</a>
# </td>
# ...

# %%
table1 = soup.find_all('table')[1]

# %%
print(table1)
# Out:
# <table class="wikitable sortable" id="constituents">
# <tbody><tr>
# <th>Company
# </th>
# <th>Symbol
# </th>
# <th>Ticker Number
# </th>
# <th>Sector
# </th>
# <th>Entry date
# </th></tr>
# <tr>
# <th><a href="/wiki/Adani_Ports_%26_SEZ" title="Adani Ports &amp; SEZ">Adani Ports &amp; SEZ</a>
# </th>
# <td>ADANIPORTS.BO
# </td>
# <td>532921
# </td>
# <td><a class="mw-redirect" href="/wiki/Ports" title="Ports">Ports</a> &amp; <a href="/wiki/Port_management" title="Port management">Port services</a>
# </td>
# <td>24 June 2024<sup class="reference" id="cite_ref-jun24_8-0"><a href="#cite_note-jun24-8"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th><a href="/wiki/Asian_Paints" title="Asian Paints">Asian Paints</a>
# </th>
# <td>ASIANPAINT.BO
# </td>
# <td>500820
# </td>
# <td><a href="/wiki/Paint" title="Paint">Paints</a>
# </td>
# ...

# %%
comp_titles = table1.find_all('th')[0:5]    # we get all headers and use list 1:5 for headers names

# %%
comp_titles
# Out:
# [<th>Company
#  </th>,
#  <th>Symbol
#  </th>,
#  <th>Ticker Number
#  </th>,
#  <th>Sector
#  </th>,
#  <th>Entry date
#  </th>]

# %%
comp_table_titles = [title.text.strip() for title in comp_titles]   # strip() funt use to get only text and remove unwanted data

print(comp_table_titles)
# Out:
# ['Company', 'Symbol', 'Ticker Number', 'Sector', 'Entry date']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = comp_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Company, Symbol, Ticker Number, Sector, Entry date]
# Index: []

# %%
column_data1 = table1.find_all('tr')[1:]

# %%
column_data1
# Out:
# [<tr>
#  <th><a href="/wiki/Adani_Ports_%26_SEZ" title="Adani Ports &amp; SEZ">Adani Ports &amp; SEZ</a>
#  </th>
#  <td>ADANIPORTS.BO
#  </td>
#  <td>532921
#  </td>
#  <td><a class="mw-redirect" href="/wiki/Ports" title="Ports">Ports</a> &amp; <a href="/wiki/Port_management" title="Port management">Port services</a>
#  </td>
#  <td>24 June 2024<sup class="reference" id="cite_ref-jun24_8-0"><a href="#cite_note-jun24-8"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
#  </td></tr>,
#  <tr>
#  <th><a href="/wiki/Asian_Paints" title="Asian Paints">Asian Paints</a>
#  </th>
#  <td>ASIANPAINT.BO
#  </td>
#  <td>500820
#  </td>
#  <td><a href="/wiki/Paint" title="Paint">Paints</a>
#  </td>
#  <td>21 December 2015<sup class="reference" id="cite_ref-:2_9-0"><a href="#cite_note-:2-9"><span class="cite-bracket">[</span>9<span class="cite-bracket">]</span></a></sup>
#  </td></tr>,
#  <tr>
#  <th><a href="/wiki/Axis_Bank" title="Axis Bank">Axis Bank</a>
# ...

# %%
for row in column_data1:
    row1_data = row.find_all('th')
    individual_row_data = [data.text for data in row_data]
    
    
    length = len(df)
    df.loc[length] = individual_row_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 7
#       3 individual_row_data = [data.text for data in row_data]
#       6 length = len(df)
# ----> 7 df.loc[length] = individual_row_data
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# -> 1825         self._setitem_with_indexer_missing(indexer, value)
#    1826         return
#    1828 if name == "loc":
# ...

# %%
df
# Out:
#            Symbol Ticker Number                         Sector  \
# 0   ADANIPORTS.BO        532921          Ports & Port services
# 1   ASIANPAINT.BO        500820                         Paints
# 2     AXISBANK.BO        532215              Banking - Private
# 3   BAJFINANCE.BO        500034                 Finance (NBFC)
# 4   BAJAJFINSV.BO        532978           Finance (Investment)
# 5   BHARTIARTL.BO        532454             Telecommunications
# 6      HCLTECH.BO        532281       IT Services & Consulting
# 7     HDFCBANK.BO        500180              Banking - Private
# 8   HINDUNILVR.BO        500696                           FMCG
# 9    ICICIBANK.BO        532174              Banking - Private
# 10  INDUSINDBK.BO        532187              Banking - Private
# 11        INFY.BO        500209       IT Services & Consulting
# 12         ITC.BO        500875              Cigarettes & FMCG
# 13    JSWSTEEL.BO        500228                          Steel
# ...
